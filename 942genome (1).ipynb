# %%
# !pip install biopython

# %%
from Bio.Seq import Seq
from Bio import  SeqIO
from Bio.Restriction import *

r=RestrictionBatch()
path = "F:/TEST/tb/ncbi_dataset/data"
import os



dir_list = os.listdir(path)
P1="TGCTTAACACATGCAAGTCGAACG"
P=Seq("GTTTCCCGCTTAGATGCTTTCAG").reverse_complement()
P2=str(P)

for i in dir_list:
    inpu = os.listdir(str(path) + "/" + str(i))
    for s in inpu:
        if s.__contains__(i):
            FASTAFILE = SeqIO.parse(str(path) + "/" + str(i) + "/" + str(s), 'fasta')
            for fasta in FASTAFILE:
                NAME, SEQUENCE, desc = str(fasta.name), str(fasta.seq), str(fasta.description)

                if P1 in SEQUENCE:
                    if P2 in SEQUENCE:
                        subsequence = SEQUENCE[SEQUENCE.index(str(P1)):SEQUENCE.index(str(P2)) + len( str(P2))]
                        try:
                            sorttt = []
                            g = Tsp45I.catalyze(Seq(subsequence))
                            if len(g) < 2:
                                break
                            for f in g:
                                if len(f) in sorttt:
                                    continue
                                if len(f) >= 50:
                                    sorttt.append(len(f))
                            sorttt.sort()
                            print(desc, sorttt)
                        except:
                            pass
                else:
                    m = str(Seq(fasta.seq).complement())
                    m = m[::-1]
                    if P1 in m:
                        if P2 in m:
                            assemply_sequence = m[m.index(str(P1)):m.index(str(P2)) + len(str(P2))]
                            try:
                                sorttt = []
                                g = Tsp45I.catalyze(Seq(assemply_sequence))
                                if len(g) < 2:
                                    break
                                for f in g:
                                    if len(f) in sorttt:
                                        continue
                                    if len(f) >= 50:
                                        sorttt.append(len(f))
                                sorttt.sort()
                                print(desc, sorttt)
                            except:
                                pass
# Out:
# NC_002755.2 Mycobacterium tuberculosis CDC1551, complete sequence [96, 110, 198, 211, 1139, 1248, 1768]
# NC_008769.1 Mycobacterium tuberculosis variant bovis BCG str. Pasteur 1173P2, complete sequence [96, 110, 198, 211, 1139, 1248, 1768]
# NC_012207.1 Mycobacterium tuberculosis variant bovis BCG str. Tokyo 172, complete sequence [96, 110, 198, 211, 1139, 1248, 1768]
# NC_009525.1 Mycobacterium tuberculosis H37Ra, complete sequence [96, 110, 198, 211, 1139, 1248, 1768]
# NC_009565.1 Mycobacterium tuberculosis F11, complete sequence [96, 110, 198, 211, 1139, 1248, 1768]
# NC_012943.1 Mycobacterium tuberculosis KZN 1435, complete sequence [96, 110, 198, 211, 1139, 1248, 1769]
# NC_022350.1 Mycobacterium tuberculosis str. Haarlem, complete sequence [96, 110, 198, 211, 1139, 1248, 1768]
# NC_016768.1 Mycobacterium tuberculosis KZN 4207, complete sequence [96, 110, 198, 211, 1139, 1248, 1768]
# ...

# %%
from Bio.Seq import Seq
from Bio import  SeqIO
from Bio.Restriction import *

r=RestrictionBatch()
path = "F:/dr ibrhim/ncbi/africanum/ncbi_dataset/data"
import os



dir_list = os.listdir(path)
P1="TGCTTAACACATGCAAGTCGAACG"
P=Seq("GTTTCCCGCTTAGATGCTTTCAG").reverse_complement()
P2=str(P)

for i in dir_list:
    inpu = os.listdir(str(path) + "/" + str(i))
    for s in inpu:
        if s.__contains__(i):
            FASTAFILE = SeqIO.parse(str(path) + "/" + str(i) + "/" + str(s), 'fasta')
            for fasta in FASTAFILE:
                NAME, SEQUENCE, desc = str(fasta.name), str(fasta.seq), str(fasta.description)

                if P1 in SEQUENCE:
                    if P2 in SEQUENCE:
                        subsequence = SEQUENCE[SEQUENCE.index(str(P1)):SEQUENCE.index(str(P2)) + len( str(P2))]
                        try:
                            sorttt = []
                            g = Tsp45I.catalyze(Seq(subsequence))
                            if len(g) < 2:
                                break
                            for f in g:
                                if len(f) in sorttt:
                                    continue
                                if len(f) >= 50:
                                    sorttt.append(len(f))
                            sorttt.sort()
                            print(desc, sorttt)
                        except:
                            pass
                else:
                    m = str(Seq(fasta.seq).complement())
                    m = m[::-1]
                    if P1 in m:
                        if P2 in m:
                            assemply_sequence = m[m.index(str(P1)):m.index(str(P2)) + len(str(P2))]
                            try:
                                sorttt = []
                                g = Tsp45I.catalyze(Seq(assemply_sequence))
                                if len(g) < 2:
                                    break
                                for f in g:
                                    if len(f) in sorttt:
                                        continue
                                    if len(f) >= 50:
                                        sorttt.append(len(f))
                                sorttt.sort()
                                print(desc, sorttt)
                            except:
                                pass
# Out:
# NC_015758.1 Mycobacterium tuberculosis variant africanum GM041182, complete sequence [96, 110, 200, 331, 940, 1545, 1768]
# NZ_CP014617.1 Mycobacterium tuberculosis variant africanum strain UT307 chromosome [96, 110, 200, 331, 940, 1545, 1768]
# NZ_LR993210.1 Mycobacterium tuberculosis variant africanum isolate Various chromosome MAF01, whole genome shotgun sequence [96, 110, 200, 331, 940, 1545, 1768]
# NZ_LR993208.1 Mycobacterium tuberculosis variant africanum isolate Various chromosome MAF65, whole genome shotgun sequence [96, 110, 200, 331, 940, 1545, 1768]

# %%
from Bio.Seq import Seq
from Bio import SeqIO
from Bio.Restriction import *
import pandas as pd
import os

# change path base to your device
path = "F:/dr ibrhim/ncbi/basiliense/ncbi_dataset/data"

P1 = "TGCTTAACACATGCAAGTCGAACG"
P = Seq("GTTTCCCGCTTAGATGCTTTCAG").reverse_complement()
P2 = str(P)

results = []   # store results for dataframe

dir_list = os.listdir(path)

for i in dir_list:
    inpu = os.listdir(os.path.join(path, i))
    for s in inpu:
        if s.__contains__(i):
            FASTAFILE = SeqIO.parse(os.path.join(path, i, s), 'fasta')
            for fasta in FASTAFILE:
                NAME, SEQUENCE, desc = str(fasta.name), str(fasta.seq), str(fasta.description)

                # Forward strand
                if P1 in SEQUENCE and P2 in SEQUENCE:
                    subsequence = SEQUENCE[SEQUENCE.index(P1):SEQUENCE.index(P2) + len(P2)]
                    try:
                        sorttt = []
                        g = Tsp45I.catalyze(Seq(subsequence))
                        if len(g) < 2:
                            continue
                        for f in g:
                            if len(f) not in sorttt and len(f) >= 50:
                                sorttt.append(len(f))
                        sorttt.sort()
                        results.append({
                                "Name": NAME,
                                "Description": desc,
                                "Fragment_Length": sorttt
                            })
                    except:
                        pass

                # Reverse complement strand
                else:
                    m = str(Seq(fasta.seq).complement())[::-1]
                    if P1 in m and P2 in m:
                        assemply_sequence = m[m.index(P1):m.index(P2) + len(P2)]
                        try:
                            sorttt = []
                            g = Tsp45I.catalyze(Seq(assemply_sequence))
                            if len(g) < 2:
                                continue
                            for f in g:
                                if len(f) not in sorttt and len(f) >= 50:
                                    sorttt.append(len(f))
                            sorttt.sort()
                            results.append({
                                    "Name": NAME,
                                    "Description": desc,
                                    "Fragment_Length": sorttt
                                })
                        except:
                            pass

# Create DataFrame
df = pd.DataFrame(results)

# Print full table
print(df.to_string(index=False))

# Optional: save results
# df.to_excel("restriction_results.xlsx", index=False)
# df.to_csv("restriction_results.csv", index=False)
# Out:
#          Name                                                                           Description             Fragment_Length
# NZ_LR130759.1 NZ_LR130759.1 Mycobacterium basiliense isolate 901379 chromosome I, complete sequence [308, 452, 892, 1347, 1742]

# %%
from Bio.Seq import Seq
from Bio import SeqIO
from Bio.Restriction import *
import pandas as pd
import os

# change path base to your device
path = "F:/dr ibrhim/ncbi/bovis"

P1 = "TGCTTAACACATGCAAGTCGAACG"
P = Seq("GTTTCCCGCTTAGATGCTTTCAG").reverse_complement()
P2 = str(P)

results = []   # store results for dataframe

dir_list = os.listdir(path)

for i in dir_list:
    inpu = os.listdir(os.path.join(path, i))
    for s in inpu:
        if s.__contains__(i):
            FASTAFILE = SeqIO.parse(os.path.join(path, i, s), 'fasta')
            for fasta in FASTAFILE:
                NAME, SEQUENCE, desc = str(fasta.name), str(fasta.seq), str(fasta.description)

                # Forward strand
                if P1 in SEQUENCE and P2 in SEQUENCE:
                    subsequence = SEQUENCE[SEQUENCE.index(P1):SEQUENCE.index(P2) + len(P2)]
                    try:
                        sorttt = []
                        g = Tsp45I.catalyze(Seq(subsequence))
                        if len(g) < 2:
                            continue
                        for f in g:
                            if len(f) not in sorttt and len(f) >= 50:
                                sorttt.append(len(f))
                        sorttt.sort()
                        results.append({
                                "Name": NAME,
                                "Description": desc,
                                "Fragment_Length": sorttt
                            })
                    except:
                        pass

                # Reverse complement strand
                else:
                    m = str(Seq(fasta.seq).complement())[::-1]
                    if P1 in m and P2 in m:
                        assemply_sequence = m[m.index(P1):m.index(P2) + len(P2)]
                        try:
                            sorttt = []
                            g = Tsp45I.catalyze(Seq(assemply_sequence))
                            if len(g) < 2:
                                continue
                            for f in g:
                                if len(f) not in sorttt and len(f) >= 50:
                                    sorttt.append(len(f))
                            sorttt.sort()
                            results.append({
                                    "Name": NAME,
                                    "Description": desc,
                                    "Fragment_Length": sorttt
                                })
                        except:
                            pass

# Create DataFrame
df = pd.DataFrame(results)

# Print full table
print(df.to_string(index=False))

# Optional: save results
# df.to_excel("restriction_results.xlsx", index=False)
# df.to_csv("restriction_results.csv", index=False)
# Out:
#          Name                                                                                                                                               Description                       Fragment_Length
#   NC_008769.1                                                         NC_008769.1 1 Mycobacterium tuberculosis variant bovis BCG str. Pasteur 1173P2, complete sequence [96, 110, 198, 232, 1139, 1520, 1700]
#   NC_012207.1                                                              NC_012207.1 1 Mycobacterium tuberculosis variant bovis BCG str. Tokyo 172, complete sequence [96, 110, 198, 232, 1139, 1520, 1700]
# NZ_CP003494.1                                      NZ_CP003494.1 1 Mycobacterium tuberculosis variant bovis BCG str. ATCC 35743 strain Tice chromosome, complete genome [96, 110, 198, 232, 1139, 1520, 1700]
# ...

# %%
from Bio.Seq import Seq
from Bio import SeqIO
from Bio.Restriction import *
import pandas as pd
import os

# change path base to your device
path = "F:/dr ibrhim/ncbi/canetti/ncbi_dataset/data"

P1 = "TGCTTAACACATGCAAGTCGAACG"
P = Seq("GTTTCCCGCTTAGATGCTTTCAG").reverse_complement()
P2 = str(P)

results = []   # store results for dataframe

dir_list = os.listdir(path)

for i in dir_list:
    inpu = os.listdir(os.path.join(path, i))
    for s in inpu:
        if s.__contains__(i):
            FASTAFILE = SeqIO.parse(os.path.join(path, i, s), 'fasta')
            for fasta in FASTAFILE:
                NAME, SEQUENCE, desc = str(fasta.name), str(fasta.seq), str(fasta.description)

                # Forward strand
                if P1 in SEQUENCE and P2 in SEQUENCE:
                    subsequence = SEQUENCE[SEQUENCE.index(P1):SEQUENCE.index(P2) + len(P2)]
                    try:
                        sorttt = []
                        g = Tsp45I.catalyze(Seq(subsequence))
                        if len(g) < 2:
                            continue
                        for f in g:
                            if len(f) not in sorttt and len(f) >= 50:
                                sorttt.append(len(f))
                        sorttt.sort()
                        results.append({
                                "Name": NAME,
                                "Description": desc,
                                "Fragment_Length": sorttt
                            })
                    except:
                        pass

                # Reverse complement strand
                else:
                    m = str(Seq(fasta.seq).complement())[::-1]
                    if P1 in m and P2 in m:
                        assemply_sequence = m[m.index(P1):m.index(P2) + len(P2)]
                        try:
                            sorttt = []
                            g = Tsp45I.catalyze(Seq(assemply_sequence))
                            if len(g) < 2:
                                continue
                            for f in g:
                                if len(f) not in sorttt and len(f) >= 50:
                                    sorttt.append(len(f))
                            sorttt.sort()
                            results.append({
                                    "Name": NAME,
                                    "Description": desc,
                                    "Fragment_Length": sorttt
                                })
                        except:
                            pass

# Create DataFrame
df = pd.DataFrame(results)

# Print full table
print(df.to_string(index=False))

# Optional: save results
# df.to_excel("restriction_results.xlsx", index=False)
# df.to_csv("restriction_results.csv", index=False)
# Out:
#          Name                                                                                                              Description                       Fragment_Length
#   NC_015848.1                                                     NC_015848.1 Mycobacterium canettii CIPT 140010059, complete sequence [96, 110, 198, 232, 1139, 1346, 1840]
#   NC_019951.1                                                     NC_019951.1 Mycobacterium canettii CIPT 140070010, complete sequence [96, 110, 198, 232, 1139, 1346, 1840]
#   NC_019950.1                                                     NC_019950.1 Mycobacterium canettii CIPT 140060008, complete sequence [96, 110, 198, 232, 1139, 1346, 1840]
#   NC_019952.1                                                     NC_019952.1 Mycobacterium canettii CIPT 140070017, complete sequence [96, 110, 198, 232, 1139, 1346, 1840]
# ...

# %%
from Bio.Seq import Seq
from Bio import SeqIO
from Bio.Restriction import *
import pandas as pd
import os

# change path base to your device
path = "F:/dr ibrhim/ncbi/conspicuum/ncbi_dataset/data"

P1 = "TGCTTAACACATGCAAGTCGAACG"
P = Seq("GTTTCCCGCTTAGATGCTTTCAG").reverse_complement()
P2 = str(P)

results = []   # store results for dataframe

dir_list = os.listdir(path)

for i in dir_list:
    inpu = os.listdir(os.path.join(path, i))
    for s in inpu:
        if s.__contains__(i):
            FASTAFILE = SeqIO.parse(os.path.join(path, i, s), 'fasta')
            for fasta in FASTAFILE:
                NAME, SEQUENCE, desc = str(fasta.name), str(fasta.seq), str(fasta.description)

                # Forward strand
                if P1 in SEQUENCE and P2 in SEQUENCE:
                    subsequence = SEQUENCE[SEQUENCE.index(P1):SEQUENCE.index(P2) + len(P2)]
                    try:
                        sorttt = []
                        g = Tsp45I.catalyze(Seq(subsequence))
                        if len(g) < 2:
                            continue
                        for f in g:
                            if len(f) not in sorttt and len(f) >= 50:
                                sorttt.append(len(f))
                        sorttt.sort()
                        results.append({
                                "Name": NAME,
                                "Description": desc,
                                "Fragment_Length": sorttt
                            })
                    except:
                        pass

                # Reverse complement strand
                else:
                    m = str(Seq(fasta.seq).complement())[::-1]
                    if P1 in m and P2 in m:
                        assemply_sequence = m[m.index(P1):m.index(P2) + len(P2)]
                        try:
                            sorttt = []
                            g = Tsp45I.catalyze(Seq(assemply_sequence))
                            if len(g) < 2:
                                continue
                            for f in g:
                                if len(f) not in sorttt and len(f) >= 50:
                                    sorttt.append(len(f))
                            sorttt.sort()
                            results.append({
                                    "Name": NAME,
                                    "Description": desc,
                                    "Fragment_Length": sorttt
                                })
                        except:
                            pass

# Create DataFrame
df = pd.DataFrame(results)

# Print full table
print(df.to_string(index=False))

# Optional: save results
# df.to_excel("restriction_results.xlsx", index=False)
# df.to_csv("restriction_results.csv", index=False)
# Out:
#          Name                                                        Description             Fragment_Length
# NZ_AP022613.1 NZ_AP022613.1 Mycobacterium conspicuum strain JCM 14738 chromosome [95, 209, 1139, 1248, 2039]

# %%
from Bio.Seq import Seq
from Bio import SeqIO
from Bio.Restriction import *
import pandas as pd
import os

# change path base to your device
path = "F:/dr ibrhim/ncbi/cookii/ncbi_dataset/data"

P1 = "TGCTTAACACATGCAAGTCGAACG"
P = Seq("GTTTCCCGCTTAGATGCTTTCAG").reverse_complement()
P2 = str(P)

results = []   # store results for dataframe

dir_list = os.listdir(path)

for i in dir_list:
    inpu = os.listdir(os.path.join(path, i))
    for s in inpu:
        if s.__contains__(i):
            FASTAFILE = SeqIO.parse(os.path.join(path, i, s), 'fasta')
            for fasta in FASTAFILE:
                NAME, SEQUENCE, desc = str(fasta.name), str(fasta.seq), str(fasta.description)

                # Forward strand
                if P1 in SEQUENCE and P2 in SEQUENCE:
                    subsequence = SEQUENCE[SEQUENCE.index(P1):SEQUENCE.index(P2) + len(P2)]
                    try:
                        sorttt = []
                        g = Tsp45I.catalyze(Seq(subsequence))
                        if len(g) < 2:
                            continue
                        for f in g:
                            if len(f) not in sorttt and len(f) >= 50:
                                sorttt.append(len(f))
                        sorttt.sort()
                        results.append({
                                "Name": NAME,
                                "Description": desc,
                                "Fragment_Length": sorttt
                            })
                    except:
                        pass

                # Reverse complement strand
                else:
                    m = str(Seq(fasta.seq).complement())[::-1]
                    if P1 in m and P2 in m:
                        assemply_sequence = m[m.index(P1):m.index(P2) + len(P2)]
                        try:
                            sorttt = []
                            g = Tsp45I.catalyze(Seq(assemply_sequence))
                            if len(g) < 2:
                                continue
                            for f in g:
                                if len(f) not in sorttt and len(f) >= 50:
                                    sorttt.append(len(f))
                            sorttt.sort()
                            results.append({
                                    "Name": NAME,
                                    "Description": desc,
                                    "Fragment_Length": sorttt
                                })
                        except:
                            pass

# Create DataFrame
df = pd.DataFrame(results)

# Print full table
print(df.to_string(index=False))

# Optional: save results
# df.to_excel("restriction_results.xlsx", index=False)
# df.to_csv("restriction_results.csv", index=False)
# Out:
#          Name                                                                     Description                  Fragment_Length
# NZ_AP022569.1 NZ_AP022569.1 Mycobacterium cookii strain JCM 12404 chromosome, complete genome [109, 423, 592, 928, 1346, 1379]

# %%
from Bio.Seq import Seq
from Bio import SeqIO
from Bio.Restriction import *
import pandas as pd
import os

# change path base to your device
path = "F:/dr ibrhim/ncbi/florentium/ncbi_dataset/data"

P1 = "TGCTTAACACATGCAAGTCGAACG"
P = Seq("GTTTCCCGCTTAGATGCTTTCAG").reverse_complement()
P2 = str(P)

results = []   # store results for dataframe

dir_list = os.listdir(path)

for i in dir_list:
    inpu = os.listdir(os.path.join(path, i))
    for s in inpu:
        if s.__contains__(i):
            FASTAFILE = SeqIO.parse(os.path.join(path, i, s), 'fasta')
            for fasta in FASTAFILE:
                NAME, SEQUENCE, desc = str(fasta.name), str(fasta.seq), str(fasta.description)

                # Forward strand
                if P1 in SEQUENCE and P2 in SEQUENCE:
                    subsequence = SEQUENCE[SEQUENCE.index(P1):SEQUENCE.index(P2) + len(P2)]
                    try:
                        sorttt = []
                        g = Tsp45I.catalyze(Seq(subsequence))
                        if len(g) < 2:
                            continue
                        for f in g:
                            if len(f) not in sorttt and len(f) >= 50:
                                sorttt.append(len(f))
                        sorttt.sort()
                        results.append({
                                "Name": NAME,
                                "Description": desc,
                                "Fragment_Length": sorttt
                            })
                    except:
                        pass

                # Reverse complement strand
                else:
                    m = str(Seq(fasta.seq).complement())[::-1]
                    if P1 in m and P2 in m:
                        assemply_sequence = m[m.index(P1):m.index(P2) + len(P2)]
                        try:
                            sorttt = []
                            g = Tsp45I.catalyze(Seq(assemply_sequence))
                            if len(g) < 2:
                                continue
                            for f in g:
                                if len(f) not in sorttt and len(f) >= 50:
                                    sorttt.append(len(f))
                            sorttt.sort()
                            results.append({
                                    "Name": NAME,
                                    "Description": desc,
                                    "Fragment_Length": sorttt
                                })
                        except:
                            pass

# Create DataFrame
df = pd.DataFrame(results)

# Print full table
print(df.to_string(index=False))

# Optional: save results
# df.to_excel("restriction_results.xlsx", index=False)
# df.to_csv("restriction_results.csv", index=False)
# Out:
#          Name                                                                          Description             Fragment_Length
# NZ_AP022576.1 NZ_AP022576.1 Mycobacterium florentinum strain JCM 14740 chromosome, complete genome [306, 408, 929, 1340, 1726]

# %%
from Bio.Seq import Seq
from Bio import SeqIO
from Bio.Restriction import *
import pandas as pd
import os

# change path base to your device
path = "F:/dr ibrhim/ncbi/florentium/ncbi_dataset/data"

P1 = "TGCTTAACACATGCAAGTCGAACG"
P = Seq("GTTTCCCGCTTAGATGCTTTCAG").reverse_complement()
P2 = str(P)

results = []   # store results for dataframe

dir_list = os.listdir(path)

for i in dir_list:
    inpu = os.listdir(os.path.join(path, i))
    for s in inpu:
        if s.__contains__(i):
            FASTAFILE = SeqIO.parse(os.path.join(path, i, s), 'fasta')
            for fasta in FASTAFILE:
                NAME, SEQUENCE, desc = str(fasta.name), str(fasta.seq), str(fasta.description)

                # Forward strand
                if P1 in SEQUENCE and P2 in SEQUENCE:
                    subsequence = SEQUENCE[SEQUENCE.index(P1):SEQUENCE.index(P2) + len(P2)]
                    try:
                        sorttt = []
                        g = Tsp45I.catalyze(Seq(subsequence))
                        if len(g) < 2:
                            continue
                        for f in g:
                            if len(f) not in sorttt and len(f) >= 50:
                                sorttt.append(len(f))
                        sorttt.sort()
                        results.append({
                                "Name": NAME,
                                "Description": desc,
                                "Fragment_Length": sorttt
                            })
                    except:
                        pass

                # Reverse complement strand
                else:
                    m = str(Seq(fasta.seq).complement())[::-1]
                    if P1 in m and P2 in m:
                        assemply_sequence = m[m.index(P1):m.index(P2) + len(P2)]
                        try:
                            sorttt = []
                            g = Tsp45I.catalyze(Seq(assemply_sequence))
                            if len(g) < 2:
                                continue
                            for f in g:
                                if len(f) not in sorttt and len(f) >= 50:
                                    sorttt.append(len(f))
                            sorttt.sort()
                            results.append({
                                    "Name": NAME,
                                    "Description": desc,
                                    "Fragment_Length": sorttt
                                })
                        except:
                            pass

# Create DataFrame
df = pd.DataFrame(results)

# Print full table
print(df.to_string(index=False))

# Optional: save results
# df.to_excel("restriction_results.xlsx", index=False)
# df.to_csv("restriction_results.csv", index=False)
# Out:
#          Name                                                                          Description             Fragment_Length
# NZ_AP022576.1 NZ_AP022576.1 Mycobacterium florentinum strain JCM 14740 chromosome, complete genome [306, 408, 929, 1340, 1726]

# %%
from Bio.Seq import Seq
from Bio import SeqIO
from Bio.Restriction import *
import pandas as pd
import os

# change path base to your device
path = "F:/dr ibrhim/ncbi/intracellulare/ncbi_dataset/data"

P1 = "TGCTTAACACATGCAAGTCGAACG"
P = Seq("GTTTCCCGCTTAGATGCTTTCAG").reverse_complement()
P2 = str(P)

results = []   # store results for dataframe

dir_list = os.listdir(path)

for i in dir_list:
    inpu = os.listdir(os.path.join(path, i))
    for s in inpu:
        if s.__contains__(i):
            FASTAFILE = SeqIO.parse(os.path.join(path, i, s), 'fasta')
            for fasta in FASTAFILE:
                NAME, SEQUENCE, desc = str(fasta.name), str(fasta.seq), str(fasta.description)

                # Forward strand
                if P1 in SEQUENCE and P2 in SEQUENCE:
                    subsequence = SEQUENCE[SEQUENCE.index(P1):SEQUENCE.index(P2) + len(P2)]
                    try:
                        sorttt = []
                        g = Tsp45I.catalyze(Seq(subsequence))
                        if len(g) < 2:
                            continue
                        for f in g:
                            if len(f) not in sorttt and len(f) >= 50:
                                sorttt.append(len(f))
                        sorttt.sort()
                        results.append({
                                "Name": NAME,
                                "Description": desc,
                                "Fragment_Length": sorttt
                            })
                    except:
                        pass

                # Reverse complement strand
                else:
                    m = str(Seq(fasta.seq).complement())[::-1]
                    if P1 in m and P2 in m:
                        assemply_sequence = m[m.index(P1):m.index(P2) + len(P2)]
                        try:
                            sorttt = []
                            g = Tsp45I.catalyze(Seq(assemply_sequence))
                            if len(g) < 2:
                                continue
                            for f in g:
                                if len(f) not in sorttt and len(f) >= 50:
                                    sorttt.append(len(f))
                            sorttt.sort()
                            results.append({
                                    "Name": NAME,
                                    "Description": desc,
                                    "Fragment_Length": sorttt
                                })
                        except:
                            pass

# Create DataFrame
df = pd.DataFrame(results)

# Print full table
print(df.to_string(index=False))

# Optional: save results
# df.to_excel("restriction_results.xlsx", index=False)
# df.to_csv("restriction_results.csv", index=False)
# Out:
#          Name                                                                          Description                 Fragment_Length
# NZ_CP076381.1 NZ_CP076381.1 Mycobacterium intracellulare strain S1-36A chromosome, complete genome [308, 452, 854, 889, 893, 1349]

# %%
from Bio.Seq import Seq
from Bio import SeqIO
from Bio.Restriction import *
import pandas as pd
import os

# change path base to your device
path = "F:/dr ibrhim/ncbi/florentium/ncbi_dataset/data"

P1 = "TGCTTAACACATGCAAGTCGAACG"
P = Seq("GTTTCCCGCTTAGATGCTTTCAG").reverse_complement()
P2 = str(P)

results = []   # store results for dataframe

dir_list = os.listdir(path)

for i in dir_list:
    inpu = os.listdir(os.path.join(path, i))
    for s in inpu:
        if s.__contains__(i):
            FASTAFILE = SeqIO.parse(os.path.join(path, i, s), 'fasta')
            for fasta in FASTAFILE:
                NAME, SEQUENCE, desc = str(fasta.name), str(fasta.seq), str(fasta.description)

                # Forward strand
                if P1 in SEQUENCE and P2 in SEQUENCE:
                    subsequence = SEQUENCE[SEQUENCE.index(P1):SEQUENCE.index(P2) + len(P2)]
                    try:
                        sorttt = []
                        g = Tsp45I.catalyze(Seq(subsequence))
                        if len(g) < 2:
                            continue
                        for f in g:
                            if len(f) not in sorttt and len(f) >= 50:
                                sorttt.append(len(f))
                        sorttt.sort()
                        results.append({
                                "Name": NAME,
                                "Description": desc,
                                "Fragment_Length": sorttt
                            })
                    except:
                        pass

                # Reverse complement strand
                else:
                    m = str(Seq(fasta.seq).complement())[::-1]
                    if P1 in m and P2 in m:
                        assemply_sequence = m[m.index(P1):m.index(P2) + len(P2)]
                        try:
                            sorttt = []
                            g = Tsp45I.catalyze(Seq(assemply_sequence))
                            if len(g) < 2:
                                continue
                            for f in g:
                                if len(f) not in sorttt and len(f) >= 50:
                                    sorttt.append(len(f))
                            sorttt.sort()
                            results.append({
                                    "Name": NAME,
                                    "Description": desc,
                                    "Fragment_Length": sorttt
                                })
                        except:
                            pass

# Create DataFrame
df = pd.DataFrame(results)

# Print full table
print(df.to_string(index=False))

# Optional: save results
# df.to_excel("restriction_results.xlsx", index=False)
# df.to_csv("restriction_results.csv", index=False)
# Out:
#          Name                                                                          Description             Fragment_Length
# NZ_AP022576.1 NZ_AP022576.1 Mycobacterium florentinum strain JCM 14740 chromosome, complete genome [306, 408, 929, 1340, 1726]

# %%
from Bio.Seq import Seq
from Bio import SeqIO
from Bio.Restriction import *
import pandas as pd
import os

# change path base to your device
path = "F:/dr ibrhim/ncbi/kansasii/ncbi_dataset/data"

P1 = "TGCTTAACACATGCAAGTCGAACG"
P = Seq("GTTTCCCGCTTAGATGCTTTCAG").reverse_complement()
P2 = str(P)

results = []   # store results for dataframe

dir_list = os.listdir(path)

for i in dir_list:
    inpu = os.listdir(os.path.join(path, i))
    for s in inpu:
        if s.__contains__(i):
            FASTAFILE = SeqIO.parse(os.path.join(path, i, s), 'fasta')
            for fasta in FASTAFILE:
                NAME, SEQUENCE, desc = str(fasta.name), str(fasta.seq), str(fasta.description)

                # Forward strand
                if P1 in SEQUENCE and P2 in SEQUENCE:
                    subsequence = SEQUENCE[SEQUENCE.index(P1):SEQUENCE.index(P2) + len(P2)]
                    try:
                        sorttt = []
                        g = BsaWI.catalyze(Seq(subsequence))
                        if len(g) < 2:
                            continue
                        for f in g:
                            if len(f) not in sorttt and len(f) >= 50:
                                sorttt.append(len(f))
                        sorttt.sort()
                        results.append({
                                "Name": NAME,
                                "Description": desc,
                                "Fragment_Length": sorttt
                            })
                    except:
                        pass

                # Reverse complement strand
                else:
                    m = str(Seq(fasta.seq).complement())[::-1]
                    if P1 in m and P2 in m:
                        assemply_sequence = m[m.index(P1):m.index(P2) + len(P2)]
                        try:
                            sorttt = []
                            g = BsaWI.catalyze(Seq(assemply_sequence))
                            if len(g) < 2:
                                continue
                            for f in g:
                                if len(f) not in sorttt and len(f) >= 50:
                                    sorttt.append(len(f))
                            sorttt.sort()
                            results.append({
                                    "Name": NAME,
                                    "Description": desc,
                                    "Fragment_Length": sorttt
                                })
                        except:
                            pass

# Create DataFrame
df = pd.DataFrame(results)

# Print full table
print(df.to_string(index=False))

# Optional: save results
# df.to_excel("restriction_results.xlsx", index=False)
# df.to_csv("restriction_results.csv", index=False)
# Out:
#          Name                                                                           Description                            Fragment_Length
#   NC_022663.1                      NC_022663.1 Mycobacterium kansasii ATCC 12478, complete sequence [123, 164, 225, 360, 373, 798, 1063, 1631]
# NZ_CP019883.1                            NZ_CP019883.1 Mycobacterium kansasii strain 1MK chromosome [123, 164, 225, 360, 373, 798, 1063, 1631]
# NZ_CP019884.1                            NZ_CP019884.1 Mycobacterium kansasii strain 4MK chromosome [123, 164, 225, 360, 373, 798, 1063, 1631]
# NZ_CP019885.1                            NZ_CP019885.1 Mycobacterium kansasii strain 6MK chromosome [123, 164, 225, 360, 373, 798, 1063, 1631]
# NZ_CP019886.1                           NZ_CP019886.1 Mycobacterium kansasii strain 10MK chromosome [123, 164, 225, 360, 373, 798, 1063, 1631]
# ...

# %%
from Bio.Seq import Seq
from Bio import SeqIO
from Bio.Restriction import *
import pandas as pd
import os

# change path base to your device
path = "F:/dr ibrhim/ncbi/lacus/ncbi_dataset/data"

P1 = "TGCTTAACACATGCAAGTCGAACG"
P = Seq("GTTTCCCGCTTAGATGCTTTCAG").reverse_complement()
P2 = str(P)

results = []   # store results for dataframe

dir_list = os.listdir(path)

for i in dir_list:
    inpu = os.listdir(os.path.join(path, i))
    for s in inpu:
        if s.__contains__(i):
            FASTAFILE = SeqIO.parse(os.path.join(path, i, s), 'fasta')
            for fasta in FASTAFILE:
                NAME, SEQUENCE, desc = str(fasta.name), str(fasta.seq), str(fasta.description)

                # Forward strand
                if P1 in SEQUENCE and P2 in SEQUENCE:
                    subsequence = SEQUENCE[SEQUENCE.index(P1):SEQUENCE.index(P2) + len(P2)]
                    try:
                        sorttt = []
                        g = Tsp45I.catalyze(Seq(subsequence))
                        if len(g) < 2:
                            continue
                        for f in g:
                            if len(f) not in sorttt and len(f) >= 50:
                                sorttt.append(len(f))
                        sorttt.sort()
                        results.append({
                                "Name": NAME,
                                "Description": desc,
                                "Fragment_Length": sorttt
                            })
                    except:
                        pass

                # Reverse complement strand
                else:
                    m = str(Seq(fasta.seq).complement())[::-1]
                    if P1 in m and P2 in m:
                        assemply_sequence = m[m.index(P1):m.index(P2) + len(P2)]
                        try:
                            sorttt = []
                            g = Tsp45I.catalyze(Seq(assemply_sequence))
                            if len(g) < 2:
                                continue
                            for f in g:
                                if len(f) not in sorttt and len(f) >= 50:
                                    sorttt.append(len(f))
                            sorttt.sort()
                            results.append({
                                    "Name": NAME,
                                    "Description": desc,
                                    "Fragment_Length": sorttt
                                })
                        except:
                            pass

# Create DataFrame
df = pd.DataFrame(results)

# Print full table
print(df.to_string(index=False))

# Optional: save results
# df.to_excel("restriction_results.xlsx", index=False)
# df.to_csv("restriction_results.csv", index=False)
# Out:
#          Name                                                                                               Description                   Fragment_Length
# NZ_AP022581.1                            NZ_AP022581.1 Mycobacterium lacus strain JCM 15657 chromosome, complete genome [209, 308, 430, 1140, 1338, 1344]
# NZ_OY970455.1 NZ_OY970455.1 Mycobacterium lacus strain DSM 44577 isolate human chromosome Mlac_44577, complete sequence [209, 308, 430, 1140, 1338, 1344]

# %%
from Bio.Seq import Seq
from Bio import SeqIO
from Bio.Restriction import *
import pandas as pd
import os

# change path base to your device
path = "F:/dr ibrhim/ncbi/leprae/ncbi_dataset/data"

P1 = "TGCTTAACACATGCAAGTCGAACG"
P = Seq("GTTTCCCGCTTAGATGCTTTCAG").reverse_complement()
P2 = str(P)

results = []   # store results for dataframe

dir_list = os.listdir(path)

for i in dir_list:
    inpu = os.listdir(os.path.join(path, i))
    for s in inpu:
        if s.__contains__(i):
            FASTAFILE = SeqIO.parse(os.path.join(path, i, s), 'fasta')
            for fasta in FASTAFILE:
                NAME, SEQUENCE, desc = str(fasta.name), str(fasta.seq), str(fasta.description)

                # Forward strand
                if P1 in SEQUENCE and P2 in SEQUENCE:
                    subsequence = SEQUENCE[SEQUENCE.index(P1):SEQUENCE.index(P2) + len(P2)]
                    try:
                        sorttt = []
                        g = Tsp45I.catalyze(Seq(subsequence))
                        if len(g) < 2:
                            continue
                        for f in g:
                            if len(f) not in sorttt and len(f) >= 50:
                                sorttt.append(len(f))
                        sorttt.sort()
                        results.append({
                                "Name": NAME,
                                "Description": desc,
                                "Fragment_Length": sorttt
                            })
                    except:
                        pass

                # Reverse complement strand
                else:
                    m = str(Seq(fasta.seq).complement())[::-1]
                    if P1 in m and P2 in m:
                        assemply_sequence = m[m.index(P1):m.index(P2) + len(P2)]
                        try:
                            sorttt = []
                            g = Tsp45I.catalyze(Seq(assemply_sequence))
                            if len(g) < 2:
                                continue
                            for f in g:
                                if len(f) not in sorttt and len(f) >= 50:
                                    sorttt.append(len(f))
                            sorttt.sort()
                            results.append({
                                    "Name": NAME,
                                    "Description": desc,
                                    "Fragment_Length": sorttt
                                })
                        except:
                            pass

# Create DataFrame
df = pd.DataFrame(results)

# Print full table
print(df.to_string(index=False))

# Optional: save results
# df.to_excel("restriction_results.xlsx", index=False)
# df.to_csv("restriction_results.csv", index=False)
# Out:
#          Name                                                                       Description              Fragment_Length
#   NC_011896.1                 NC_011896.1 Mycobacterium leprae Br4923, complete genome sequence [223, 562, 1140, 1344, 1508]
#   NC_002677.1                            NC_002677.1 Mycobacterium leprae TN, complete sequence [223, 562, 1140, 1344, 1508]
# NZ_CP029543.1 NZ_CP029543.1 Mycobacterium leprae strain MRHRU-235-G chromosome, complete genome [223, 562, 1140, 1344, 1508]
# NZ_AP014567.1            NZ_AP014567.1 Mycobacterium leprae Kyoto-2 chromosome, complete genome [223, 562, 1140, 1344, 1508]

# %%
from Bio.Seq import Seq
from Bio import SeqIO
from Bio.Restriction import *
import pandas as pd
import os

# change path base to your device
path = "F:/dr ibrhim/ncbi/mantenii/ncbi_dataset/data"

P1 = "TGCTTAACACATGCAAGTCGAACG"
P = Seq("GTTTCCCGCTTAGATGCTTTCAG").reverse_complement()
P2 = str(P)

results = []   # store results for dataframe

dir_list = os.listdir(path)

for i in dir_list:
    inpu = os.listdir(os.path.join(path, i))
    for s in inpu:
        if s.__contains__(i):
            FASTAFILE = SeqIO.parse(os.path.join(path, i, s), 'fasta')
            for fasta in FASTAFILE:
                NAME, SEQUENCE, desc = str(fasta.name), str(fasta.seq), str(fasta.description)

                # Forward strand
                if P1 in SEQUENCE and P2 in SEQUENCE:
                    subsequence = SEQUENCE[SEQUENCE.index(P1):SEQUENCE.index(P2) + len(P2)]
                    try:
                        sorttt = []
                        g = Tsp45I.catalyze(Seq(subsequence))
                        if len(g) < 2:
                            continue
                        for f in g:
                            if len(f) not in sorttt and len(f) >= 50:
                                sorttt.append(len(f))
                        sorttt.sort()
                        results.append({
                                "Name": NAME,
                                "Description": desc,
                                "Fragment_Length": sorttt
                            })
                    except:
                        pass

                # Reverse complement strand
                else:
                    m = str(Seq(fasta.seq).complement())[::-1]
                    if P1 in m and P2 in m:
                        assemply_sequence = m[m.index(P1):m.index(P2) + len(P2)]
                        try:
                            sorttt = []
                            g = Tsp45I.catalyze(Seq(assemply_sequence))
                            if len(g) < 2:
                                continue
                            for f in g:
                                if len(f) not in sorttt and len(f) >= 50:
                                    sorttt.append(len(f))
                            sorttt.sort()
                            results.append({
                                    "Name": NAME,
                                    "Description": desc,
                                    "Fragment_Length": sorttt
                                })
                        except:
                            pass

# Create DataFrame
df = pd.DataFrame(results)

# Print full table
print(df.to_string(index=False))

# Optional: save results
# df.to_excel("restriction_results.xlsx", index=False)
# df.to_csv("restriction_results.csv", index=False)
# Out:
#          Name                                                                       Description         Fragment_Length
# NZ_AP022590.1 NZ_AP022590.1 Mycobacterium mantenii strain JCM 18113 chromosome, complete genome [308, 1341, 1346, 1750]

# %%
from Bio.Seq import Seq
from Bio import SeqIO
from Bio.Restriction import *
import pandas as pd
import os

# change path base to your device
path = "F:/dr ibrhim/ncbi/micrtio"

P1 = "TGCTTAACACATGCAAGTCGAACG"
P = Seq("GTTTCCCGCTTAGATGCTTTCAG").reverse_complement()
P2 = str(P)

results = []   # store results for dataframe

dir_list = os.listdir(path)

for i in dir_list:
    inpu = os.listdir(os.path.join(path, i))
    for s in inpu:
        if s.__contains__(i):
            FASTAFILE = SeqIO.parse(os.path.join(path, i, s), 'fasta')
            for fasta in FASTAFILE:
                NAME, SEQUENCE, desc = str(fasta.name), str(fasta.seq), str(fasta.description)

                # Forward strand
                if P1 in SEQUENCE and P2 in SEQUENCE:
                    subsequence = SEQUENCE[SEQUENCE.index(P1):SEQUENCE.index(P2) + len(P2)]
                    try:
                        sorttt = []
                        g = Tsp45I.catalyze(Seq(subsequence))
                        if len(g) < 2:
                            continue
                        for f in g:
                            if len(f) not in sorttt and len(f) >= 50:
                                sorttt.append(len(f))
                        sorttt.sort()
                        results.append({
                                "Name": NAME,
                                "Description": desc,
                                "Fragment_Length": sorttt
                            })
                    except:
                        pass

                # Reverse complement strand
                else:
                    m = str(Seq(fasta.seq).complement())[::-1]
                    if P1 in m and P2 in m:
                        assemply_sequence = m[m.index(P1):m.index(P2) + len(P2)]
                        try:
                            sorttt = []
                            g = Tsp45I.catalyze(Seq(assemply_sequence))
                            if len(g) < 2:
                                continue
                            for f in g:
                                if len(f) not in sorttt and len(f) >= 50:
                                    sorttt.append(len(f))
                            sorttt.sort()
                            results.append({
                                    "Name": NAME,
                                    "Description": desc,
                                    "Fragment_Length": sorttt
                                })
                        except:
                            pass

# Create DataFrame
df = pd.DataFrame(results)

# Print full table
print(df.to_string(index=False))

# Optional: save results
# df.to_excel("restriction_results.xlsx", index=False)
# df.to_csv("restriction_results.csv", index=False)
# Out:
#          Name                                                                                                      Description                       Fragment_Length
# NZ_LR882499.1                 NZ_LR882499.1 Mycobacterium tuberculosis variant microti OV254 isolate vole chromosome MmicOV254 [95, 110, 198, 311, 1190, 1400, 1740]
# NZ_LR882496.1 NZ_LR882496.1 Mycobacterium tuberculosis variant microti strain ATCC 35782 isolate vole chromosome MmicATCC35782 [95, 110, 198, 311, 1190, 1400, 1740]
# NZ_LR882498.1      NZ_LR882498.1 Mycobacterium tuberculosis variant microti strain Maus III isolate human chromosome MmicMaus3 [95, 110, 198, 311, 1190, 1400, 1740]
# NZ_LR882497.1       NZ_LR882497.1 Mycobacterium tuberculosis variant microti strain Maus IV isolate human chromosome MmicMaus4 [95, 110, 198, 311, 1190, 1400, 1740]
# ...

# %%
from Bio.Seq import Seq
from Bio import SeqIO
from Bio.Restriction import *
import pandas as pd
import os

# change path base to your device
path = "F:/dr ibrhim/ncbi/ncbi_avium/ncbi_dataset/data"

P1 = "TGCTTAACACATGCAAGTCGAACG"
P = Seq("GTTTCCCGCTTAGATGCTTTCAG").reverse_complement()
P2 = str(P)

results = []   # store results for dataframe

dir_list = os.listdir(path)

for i in dir_list:
    inpu = os.listdir(os.path.join(path, i))
    for s in inpu:
        if s.__contains__(i):
            FASTAFILE = SeqIO.parse(os.path.join(path, i, s), 'fasta')
            for fasta in FASTAFILE:
                NAME, SEQUENCE, desc = str(fasta.name), str(fasta.seq), str(fasta.description)

                # Forward strand
                if P1 in SEQUENCE and P2 in SEQUENCE:
                    subsequence = SEQUENCE[SEQUENCE.index(P1):SEQUENCE.index(P2) + len(P2)]
                    try:
                        sorttt = []
                        g = Tsp45I.catalyze(Seq(subsequence))
                        if len(g) < 2:
                            continue
                        for f in g:
                            if len(f) not in sorttt and len(f) >= 50:
                                sorttt.append(len(f))
                        sorttt.sort()
                        results.append({
                                "Name": NAME,
                                "Description": desc,
                                "Fragment_Length": sorttt
                            })
                    except:
                        pass

                # Reverse complement strand
                else:
                    m = str(Seq(fasta.seq).complement())[::-1]
                    if P1 in m and P2 in m:
                        assemply_sequence = m[m.index(P1):m.index(P2) + len(P2)]
                        try:
                            sorttt = []
                            g = Tsp45I.catalyze(Seq(assemply_sequence))
                            if len(g) < 2:
                                continue
                            for f in g:
                                if len(f) not in sorttt and len(f) >= 50:
                                    sorttt.append(len(f))
                            sorttt.sort()
                            results.append({
                                    "Name": NAME,
                                    "Description": desc,
                                    "Fragment_Length": sorttt
                                })
                        except:
                            pass

# Create DataFrame
df = pd.DataFrame(results)

# Print full table
print(df.to_string(index=False))

# Optional: save results
# df.to_excel("restriction_results.xlsx", index=False)
# df.to_csv("restriction_results.csv", index=False)
# Out:
#          Name                                                                                                            Description              Fragment_Length
#   NC_002944.2                                        NC_002944.2 Mycobacterium avium subsp. paratuberculosis K-10, complete sequence [228, 308, 1140, 1627, 1749]
#   NC_008595.1                                                                 NC_008595.1 Mycobacterium avium 104, complete sequence [228, 308, 1140, 1627, 1749]
# NZ_CP053749.1                             NZ_CP053749.1 Mycobacterium avium subsp. paratuberculosis S397 chromosome, complete genome [228, 308, 1140, 1627, 1749]
#   NC_021200.1                                        NC_021200.1 Mycobacterium avium subsp. paratuberculosis MAP4, complete sequence [228, 308, 1140, 1627, 1749]
# NZ_AP012555.1                                 NZ_AP012555.1 Mycobacterium avium subsp. hominissuis TH135 chromosome, complete genome [228, 308, 1140, 1627, 1749]
# ...

# %%
from Bio.Seq import Seq
from Bio import SeqIO
from Bio.Restriction import *
import pandas as pd
import os

# change path base to your device
path = "F:/dr ibrhim/ncbi/haemophilum/ncbi_dataset/data"

P1 = "TGCTTAACACATGCAAGTCGAACG"
P = Seq("GTTTCCCGCTTAGATGCTTTCAG").reverse_complement()
P2 = str(P)

results = []   # store results for dataframe

dir_list = os.listdir(path)

for i in dir_list:
    inpu = os.listdir(os.path.join(path, i))
    for s in inpu:
        if s.__contains__(i):
            FASTAFILE = SeqIO.parse(os.path.join(path, i, s), 'fasta')
            for fasta in FASTAFILE:
                NAME, SEQUENCE, desc = str(fasta.name), str(fasta.seq), str(fasta.description)

                # Forward strand
                if P1 in SEQUENCE and P2 in SEQUENCE:
                    subsequence = SEQUENCE[SEQUENCE.index(P1):SEQUENCE.index(P2) + len(P2)]
                    try:
                        sorttt = []
                        g = Tsp45I.catalyze(Seq(subsequence))
                        if len(g) < 2:
                            continue
                        for f in g:
                            if len(f) not in sorttt and len(f) >= 50:
                                sorttt.append(len(f))
                        sorttt.sort()
                        results.append({
                                "Name": NAME,
                                "Description": desc,
                                "Fragment_Length": sorttt
                            })
                    except:
                        pass

                # Reverse complement strand
                else:
                    m = str(Seq(fasta.seq).complement())[::-1]
                    if P1 in m and P2 in m:
                        assemply_sequence = m[m.index(P1):m.index(P2) + len(P2)]
                        try:
                            sorttt = []
                            g = Tsp45I.catalyze(Seq(assemply_sequence))
                            if len(g) < 2:
                                continue
                            for f in g:
                                if len(f) not in sorttt and len(f) >= 50:
                                    sorttt.append(len(f))
                            sorttt.sort()
                            results.append({
                                    "Name": NAME,
                                    "Description": desc,
                                    "Fragment_Length": sorttt
                                })
                        except:
                            pass

# Create DataFrame
df = pd.DataFrame(results)

# Print full table
print(df.to_string(index=False))

# Optional: save results
# df.to_excel("restriction_results.xlsx", index=False)
# df.to_csv("restriction_results.csv", index=False)
# Out:
#              Name                                                                                     Description         Fragment_Length
#     NZ_CP011883.2 NZ_CP011883.2 Mycobacterium haemophilum DSM 44634 strain ATCC 29548 chromosome, complete genome [210, 1140, 1344, 2079]
# NZ_LDPR01000004.1  NZ_LDPR01000004.1 Mycobacterium haemophilum strain UC3 contig_4, whole genome shotgun sequence [210, 1140, 1344, 2079]

# %%
from Bio.Seq import Seq
from Bio import SeqIO
from Bio.Restriction import *
import pandas as pd
import os

# change path base to your device
path = "F:/dr ibrhim/ncbi/paraterrae/ncbi_dataset/data"

P1 = "TGCTTAACACATGCAAGTCGAACG"
P = Seq("GTTTCCCGCTTAGATGCTTTCAG").reverse_complement()
P2 = str(P)

results = []   # store results for dataframe

dir_list = os.listdir(path)

for i in dir_list:
    inpu = os.listdir(os.path.join(path, i))
    for s in inpu:
        if s.__contains__(i):
            FASTAFILE = SeqIO.parse(os.path.join(path, i, s), 'fasta')
            for fasta in FASTAFILE:
                NAME, SEQUENCE, desc = str(fasta.name), str(fasta.seq), str(fasta.description)

                # Forward strand
                if P1 in SEQUENCE and P2 in SEQUENCE:
                    subsequence = SEQUENCE[SEQUENCE.index(P1):SEQUENCE.index(P2) + len(P2)]
                    try:
                        sorttt = []
                        g = Tsp45I.catalyze(Seq(subsequence))
                        if len(g) < 2:
                            continue
                        for f in g:
                            if len(f) not in sorttt and len(f) >= 50:
                                sorttt.append(len(f))
                        sorttt.sort()
                        results.append({
                                "Name": NAME,
                                "Description": desc,
                                "Fragment_Length": sorttt
                            })
                    except:
                        pass

                # Reverse complement strand
                else:
                    m = str(Seq(fasta.seq).complement())[::-1]
                    if P1 in m and P2 in m:
                        assemply_sequence = m[m.index(P1):m.index(P2) + len(P2)]
                        try:
                            sorttt = []
                            g = Tsp45I.catalyze(Seq(assemply_sequence))
                            if len(g) < 2:
                                continue
                            for f in g:
                                if len(f) not in sorttt and len(f) >= 50:
                                    sorttt.append(len(f))
                            sorttt.sort()
                            results.append({
                                    "Name": NAME,
                                    "Description": desc,
                                    "Fragment_Length": sorttt
                                })
                        except:
                            pass

# Create DataFrame
df = pd.DataFrame(results)

# Print full table
print(df.to_string(index=False))

# Optional: save results
# df.to_excel("restriction_results.xlsx", index=False)
# df.to_csv("restriction_results.csv", index=False)
# Out:
#          Name                                                                         Description                 Fragment_Length
# NZ_CP092488.2 NZ_CP092488.2 Mycobacterium paraterrae strain DSM 45127 chromosome, complete genome [79, 422, 596, 928, 1268, 1488]

# %%
from Bio.Seq import Seq
from Bio import SeqIO
from Bio.Restriction import *
import pandas as pd
import os

# change path base to your device
path = "F:/dr ibrhim/ncbi/paratuberculosis/ncbi_dataset/data"

P1 = "TGCTTAACACATGCAAGTCGAACG"
P = Seq("GTTTCCCGCTTAGATGCTTTCAG").reverse_complement()
P2 = str(P)

results = []   # store results for dataframe

dir_list = os.listdir(path)

for i in dir_list:
    inpu = os.listdir(os.path.join(path, i))
    for s in inpu:
        if s.__contains__(i):
            FASTAFILE = SeqIO.parse(os.path.join(path, i, s), 'fasta')
            for fasta in FASTAFILE:
                NAME, SEQUENCE, desc = str(fasta.name), str(fasta.seq), str(fasta.description)

                # Forward strand
                if P1 in SEQUENCE and P2 in SEQUENCE:
                    subsequence = SEQUENCE[SEQUENCE.index(P1):SEQUENCE.index(P2) + len(P2)]
                    try:
                        sorttt = []
                        g = Tsp45I.catalyze(Seq(subsequence))
                        if len(g) < 2:
                            continue
                        for f in g:
                            if len(f) not in sorttt and len(f) >= 50:
                                sorttt.append(len(f))
                        sorttt.sort()
                        results.append({
                                "Name": NAME,
                                "Description": desc,
                                "Fragment_Length": sorttt
                            })
                    except:
                        pass

                # Reverse complement strand
                else:
                    m = str(Seq(fasta.seq).complement())[::-1]
                    if P1 in m and P2 in m:
                        assemply_sequence = m[m.index(P1):m.index(P2) + len(P2)]
                        try:
                            sorttt = []
                            g = Tsp45I.catalyze(Seq(assemply_sequence))
                            if len(g) < 2:
                                continue
                            for f in g:
                                if len(f) not in sorttt and len(f) >= 50:
                                    sorttt.append(len(f))
                            sorttt.sort()
                            results.append({
                                    "Name": NAME,
                                    "Description": desc,
                                    "Fragment_Length": sorttt
                                })
                        except:
                            pass

# Create DataFrame
df = pd.DataFrame(results)

# Print full table
print(df.to_string(index=False))

# Optional: save results
# df.to_excel("restriction_results.xlsx", index=False)
# df.to_csv("restriction_results.csv", index=False)
# Out:
#          Name                                                                                                            Description              Fragment_Length
#   NC_002944.2                                        NC_002944.2 Mycobacterium avium subsp. paratuberculosis K-10, complete sequence [129, 350, 1140, 1429, 1748]
# NZ_CP053749.1                             NZ_CP053749.1 Mycobacterium avium subsp. paratuberculosis S397 chromosome, complete genome [129, 350, 1140, 1429, 1748]
#   NC_021200.1                                        NC_021200.1 Mycobacterium avium subsp. paratuberculosis MAP4, complete sequence [129, 350, 1140, 1429, 1748]
# NZ_CP010113.1                        NZ_CP010113.1 Mycobacterium avium subsp. paratuberculosis strain E1 chromosome, complete genome [129, 350, 1140, 1429, 1748]
# NZ_CP010114.1                       NZ_CP010114.1 Mycobacterium avium subsp. paratuberculosis strain E93 chromosome, complete genome [129, 350, 1140, 1429, 1748]
# ...

# %%
from Bio.Seq import Seq
from Bio import SeqIO
from Bio.Restriction import *
import pandas as pd
import os

# change path base to your device
path = "F:/dr ibrhim/ncbi/parmense/ncbi_dataset/data"

P1 = "TGCTTAACACATGCAAGTCGAACG"
P = Seq("GTTTCCCGCTTAGATGCTTTCAG").reverse_complement()
P2 = str(P)

results = []   # store results for dataframe

dir_list = os.listdir(path)

for i in dir_list:
    inpu = os.listdir(os.path.join(path, i))
    for s in inpu:
        if s.__contains__(i):
            FASTAFILE = SeqIO.parse(os.path.join(path, i, s), 'fasta')
            for fasta in FASTAFILE:
                NAME, SEQUENCE, desc = str(fasta.name), str(fasta.seq), str(fasta.description)

                # Forward strand
                if P1 in SEQUENCE and P2 in SEQUENCE:
                    subsequence = SEQUENCE[SEQUENCE.index(P1):SEQUENCE.index(P2) + len(P2)]
                    try:
                        sorttt = []
                        g = Tsp45I.catalyze(Seq(subsequence))
                        if len(g) < 2:
                            continue
                        for f in g:
                            if len(f) not in sorttt and len(f) >= 50:
                                sorttt.append(len(f))
                        sorttt.sort()
                        results.append({
                                "Name": NAME,
                                "Description": desc,
                                "Fragment_Length": sorttt
                            })
                    except:
                        pass

                # Reverse complement strand
                else:
                    m = str(Seq(fasta.seq).complement())[::-1]
                    if P1 in m and P2 in m:
                        assemply_sequence = m[m.index(P1):m.index(P2) + len(P2)]
                        try:
                            sorttt = []
                            g = Tsp45I.catalyze(Seq(assemply_sequence))
                            if len(g) < 2:
                                continue
                            for f in g:
                                if len(f) not in sorttt and len(f) >= 50:
                                    sorttt.append(len(f))
                            sorttt.sort()
                            results.append({
                                    "Name": NAME,
                                    "Description": desc,
                                    "Fragment_Length": sorttt
                                })
                        except:
                            pass

# Create DataFrame
df = pd.DataFrame(results)

# Print full table
print(df.to_string(index=False))

# Optional: save results
# df.to_excel("restriction_results.xlsx", index=False)
# df.to_csv("restriction_results.csv", index=False)
# Out:
#          Name                                                             Description                  Fragment_Length
#    AP022614.1 AP022614.1 Mycobacterium parmense JCM 14742 DNA, nearly complete genome [199, 210, 306, 929, 1340, 1739]
# NZ_AP022614.1        NZ_AP022614.1 Mycobacterium parmense strain JCM 14742 chromosome [199, 210, 306, 929, 1340, 1739]

# %%
from Bio.Seq import Seq
from Bio import SeqIO
from Bio.Restriction import *
import pandas as pd
import os

# change path base to your device
path = "F:/dr ibrhim/ncbi/saskatchewanse/ncbi_dataset/data"

P1 = "TGCTTAACACATGCAAGTCGAACG"
P = Seq("GTTTCCCGCTTAGATGCTTTCAG").reverse_complement()
P2 = str(P)

results = []   # store results for dataframe

dir_list = os.listdir(path)

for i in dir_list:
    inpu = os.listdir(os.path.join(path, i))
    for s in inpu:
        if s.__contains__(i):
            FASTAFILE = SeqIO.parse(os.path.join(path, i, s), 'fasta')
            for fasta in FASTAFILE:
                NAME, SEQUENCE, desc = str(fasta.name), str(fasta.seq), str(fasta.description)

                # Forward strand
                if P1 in SEQUENCE and P2 in SEQUENCE:
                    subsequence = SEQUENCE[SEQUENCE.index(P1):SEQUENCE.index(P2) + len(P2)]
                    try:
                        sorttt = []
                        g = BsaWI.catalyze(Seq(subsequence))
                        if len(g) < 2:
                            continue
                        for f in g:
                            if len(f) not in sorttt and len(f) >= 50:
                                sorttt.append(len(f))
                        sorttt.sort()
                        results.append({
                                "Name": NAME,
                                "Description": desc,
                                "Fragment_Length": sorttt
                            })
                    except:
                        pass

                # Reverse complement strand
                else:
                    m = str(Seq(fasta.seq).complement())[::-1]
                    if P1 in m and P2 in m:
                        assemply_sequence = m[m.index(P1):m.index(P2) + len(P2)]
                        try:
                            sorttt = []
                            g = BsaWI.catalyze(Seq(assemply_sequence))
                            if len(g) < 2:
                                continue
                            for f in g:
                                if len(f) not in sorttt and len(f) >= 50:
                                    sorttt.append(len(f))
                            sorttt.sort()
                            results.append({
                                    "Name": NAME,
                                    "Description": desc,
                                    "Fragment_Length": sorttt
                                })
                        except:
                            pass

# Create DataFrame
df = pd.DataFrame(results)

# Print full table
print(df.to_string(index=False))

# Optional: save results
# df.to_excel("restriction_results.xlsx", index=False)
# df.to_csv("restriction_results.csv", index=False)
# Out:
#          Name                                                                               Description                            Fragment_Length
# NZ_AP022573.1 NZ_AP022573.1 Mycobacterium saskatchewanense strain JCM 13016 chromosome, complete genome [123, 164, 225, 361, 396, 799, 1022, 1627]

# %%
from Bio.Seq import Seq
from Bio import SeqIO
from Bio.Restriction import *
import pandas as pd
import os

# change path base to your device
path = "F:/dr ibrhim/ncbi/seoulense/ncbi_dataset/data"

P1 = "TGCTTAACACATGCAAGTCGAACG"
P = Seq("GTTTCCCGCTTAGATGCTTTCAG").reverse_complement()
P2 = str(P)

results = []   # store results for dataframe

dir_list = os.listdir(path)

for i in dir_list:
    inpu = os.listdir(os.path.join(path, i))
    for s in inpu:
        if s.__contains__(i):
            FASTAFILE = SeqIO.parse(os.path.join(path, i, s), 'fasta')
            for fasta in FASTAFILE:
                NAME, SEQUENCE, desc = str(fasta.name), str(fasta.seq), str(fasta.description)

                # Forward strand
                if P1 in SEQUENCE and P2 in SEQUENCE:
                    subsequence = SEQUENCE[SEQUENCE.index(P1):SEQUENCE.index(P2) + len(P2)]
                    try:
                        sorttt = []
                        g = BsaWI.catalyze(Seq(subsequence))
                        if len(g) < 2:
                            continue
                        for f in g:
                            if len(f) not in sorttt and len(f) >= 50:
                                sorttt.append(len(f))
                        sorttt.sort()
                        results.append({
                                "Name": NAME,
                                "Description": desc,
                                "Fragment_Length": sorttt
                            })
                    except:
                        pass

                # Reverse complement strand
                else:
                    m = str(Seq(fasta.seq).complement())[::-1]
                    if P1 in m and P2 in m:
                        assemply_sequence = m[m.index(P1):m.index(P2) + len(P2)]
                        try:
                            sorttt = []
                            g = BsaWI.catalyze(Seq(assemply_sequence))
                            if len(g) < 2:
                                continue
                            for f in g:
                                if len(f) not in sorttt and len(f) >= 50:
                                    sorttt.append(len(f))
                            sorttt.sort()
                            results.append({
                                    "Name": NAME,
                                    "Description": desc,
                                    "Fragment_Length": sorttt
                                })
                        except:
                            pass

# Create DataFrame
df = pd.DataFrame(results)

# Print full table
print(df.to_string(index=False))

# Optional: save results
# df.to_excel("restriction_results.xlsx", index=False)
# df.to_csv("restriction_results.csv", index=False)
# Out:
#          Name                                                                        Description             Fragment_Length
# NZ_AP022582.1 NZ_AP022582.1 Mycobacterium seoulense strain JCM 16018 chromosome, complete genome [164, 495, 798, 1420, 1859]

# %%
from Bio.Seq import Seq
from Bio import SeqIO
from Bio.Restriction import *
import pandas as pd
import os

# change path base to your device
path = "F:/dr ibrhim/ncbi/Shiganse/ncbi_dataset/data"

P1 = "TGCTTAACACATGCAAGTCGAACG"
P = Seq("GTTTCCCGCTTAGATGCTTTCAG").reverse_complement()
P2 = str(P)

results = []   # store results for dataframe

dir_list = os.listdir(path)

for i in dir_list:
    inpu = os.listdir(os.path.join(path, i))
    for s in inpu:
        if s.__contains__(i):
            FASTAFILE = SeqIO.parse(os.path.join(path, i, s), 'fasta')
            for fasta in FASTAFILE:
                NAME, SEQUENCE, desc = str(fasta.name), str(fasta.seq), str(fasta.description)

                # Forward strand
                if P1 in SEQUENCE and P2 in SEQUENCE:
                    subsequence = SEQUENCE[SEQUENCE.index(P1):SEQUENCE.index(P2) + len(P2)]
                    try:
                        sorttt = []
                        g = Tsp45I.catalyze(Seq(subsequence))
                        if len(g) < 2:
                            continue
                        for f in g:
                            if len(f) not in sorttt and len(f) >= 50:
                                sorttt.append(len(f))
                        sorttt.sort()
                        results.append({
                                "Name": NAME,
                                "Description": desc,
                                "Fragment_Length": sorttt
                            })
                    except:
                        pass

                # Reverse complement strand
                else:
                    m = str(Seq(fasta.seq).complement())[::-1]
                    if P1 in m and P2 in m:
                        assemply_sequence = m[m.index(P1):m.index(P2) + len(P2)]
                        try:
                            sorttt = []
                            g = Tsp45I.catalyze(Seq(assemply_sequence))
                            if len(g) < 2:
                                continue
                            for f in g:
                                if len(f) not in sorttt and len(f) >= 50:
                                    sorttt.append(len(f))
                            sorttt.sort()
                            results.append({
                                    "Name": NAME,
                                    "Description": desc,
                                    "Fragment_Length": sorttt
                                })
                        except:
                            pass

# Create DataFrame
df = pd.DataFrame(results)

# Print full table
print(df.to_string(index=False))

# Optional: save results
# df.to_excel("restriction_results.xlsx", index=False)
# df.to_csv("restriction_results.csv", index=False)
# Out:
#                 Name                                                                                           Description                  Fragment_Length
#        NZ_AP018164.1                    NZ_AP018164.1 Mycobacterium shigaense strain JCM 32072 chromosome, complete genome [199, 209, 371, 929, 1343, 1650]
#        NZ_CP022927.1                          NZ_CP022927.1 Mycobacterium shigaense strain SCY chromosome, complete genome [199, 209, 371, 929, 1343, 1650]
# NZ_JAYDXR010000001.1 NZ_JAYDXR010000001.1 Mycobacterium shigaense strain 050038 contig00001, whole genome shotgun sequence [199, 209, 371, 929, 1343, 1650]

# %%
from Bio.Seq import Seq
from Bio import SeqIO
from Bio.Restriction import *
import pandas as pd
import os

# change path base to your device
path = "F:/dr ibrhim/ncbi/shinjukuense/ncbi_dataset/data"

P1 = "TGCTTAACACATGCAAGTCGAACG"
P = Seq("GTTTCCCGCTTAGATGCTTTCAG").reverse_complement()
P2 = str(P)

results = []   # store results for dataframe

dir_list = os.listdir(path)

for i in dir_list:
    inpu = os.listdir(os.path.join(path, i))
    for s in inpu:
        if s.__contains__(i):
            FASTAFILE = SeqIO.parse(os.path.join(path, i, s), 'fasta')
            for fasta in FASTAFILE:
                NAME, SEQUENCE, desc = str(fasta.name), str(fasta.seq), str(fasta.description)

                # Forward strand
                if P1 in SEQUENCE and P2 in SEQUENCE:
                    subsequence = SEQUENCE[SEQUENCE.index(P1):SEQUENCE.index(P2) + len(P2)]
                    try:
                        sorttt = []
                        g = Tsp45I.catalyze(Seq(subsequence))
                        if len(g) < 2:
                            continue
                        for f in g:
                            if len(f) not in sorttt and len(f) >= 50:
                                sorttt.append(len(f))
                        sorttt.sort()
                        results.append({
                                "Name": NAME,
                                "Description": desc,
                                "Fragment_Length": sorttt
                            })
                    except:
                        pass

                # Reverse complement strand
                else:
                    m = str(Seq(fasta.seq).complement())[::-1]
                    if P1 in m and P2 in m:
                        assemply_sequence = m[m.index(P1):m.index(P2) + len(P2)]
                        try:
                            sorttt = []
                            g = Tsp45I.catalyze(Seq(assemply_sequence))
                            if len(g) < 2:
                                continue
                            for f in g:
                                if len(f) not in sorttt and len(f) >= 50:
                                    sorttt.append(len(f))
                            sorttt.sort()
                            results.append({
                                    "Name": NAME,
                                    "Description": desc,
                                    "Fragment_Length": sorttt
                                })
                        except:
                            pass

# Create DataFrame
df = pd.DataFrame(results)

# Print full table
print(df.to_string(index=False))

# Optional: save results
# df.to_excel("restriction_results.xlsx", index=False)
# df.to_csv("restriction_results.csv", index=False)
# Out:
#                 Name                                                                                                                                 Description              Fragment_Length
#    NZ_MVIK01000018.1 NZ_MVIK01000018.1 Mycobacterium shinjukuense strain CCUG 53584 Mycobacterium_shinjukuense_CCUG53584_contig18, whole genome shotgun sequence [110, 198, 1344, 1349, 1759]
#        NZ_AP022575.1                                                       NZ_AP022575.1 Mycobacterium shinjukuense strain JCM 14233 chromosome, complete genome [110, 198, 1344, 1349, 1759]
# NZ_JACKTO010000028.1          NZ_JACKTO010000028.1 Mycobacterium shinjukuense strain DSM 45663 MSHINJUKUENSEDSM45663_contig000028, whole genome shotgun sequence [110, 198, 1344, 1349, 1759]
#        NZ_OY970454.1                            NZ_OY970454.1 Mycobacterium shinjukuense strain DSM 45663 isolate human chromosome Mshi_45663, complete sequence [110, 198, 1344, 1350, 1759]

# %%
from Bio.Seq import Seq
from Bio import SeqIO
from Bio.Restriction import *
import pandas as pd
import os

# change path base to your device
path = "F:/dr ibrhim/ncbi/shottsii/ncbi_dataset/data"

P1 = "TGCTTAACACATGCAAGTCGAACG"
P = Seq("GTTTCCCGCTTAGATGCTTTCAG").reverse_complement()
P2 = str(P)

results = []   # store results for dataframe

dir_list = os.listdir(path)

for i in dir_list:
    inpu = os.listdir(os.path.join(path, i))
    for s in inpu:
        if s.__contains__(i):
            FASTAFILE = SeqIO.parse(os.path.join(path, i, s), 'fasta')
            for fasta in FASTAFILE:
                NAME, SEQUENCE, desc = str(fasta.name), str(fasta.seq), str(fasta.description)

                # Forward strand
                if P1 in SEQUENCE and P2 in SEQUENCE:
                    subsequence = SEQUENCE[SEQUENCE.index(P1):SEQUENCE.index(P2) + len(P2)]
                    try:
                        sorttt = []
                        g = Tsp45I.catalyze(Seq(subsequence))
                        if len(g) < 2:
                            continue
                        for f in g:
                            if len(f) not in sorttt and len(f) >= 50:
                                sorttt.append(len(f))
                        sorttt.sort()
                        results.append({
                                "Name": NAME,
                                "Description": desc,
                                "Fragment_Length": sorttt
                            })
                    except:
                        pass

                # Reverse complement strand
                else:
                    m = str(Seq(fasta.seq).complement())[::-1]
                    if P1 in m and P2 in m:
                        assemply_sequence = m[m.index(P1):m.index(P2) + len(P2)]
                        try:
                            sorttt = []
                            g = Tsp45I.catalyze(Seq(assemply_sequence))
                            if len(g) < 2:
                                continue
                            for f in g:
                                if len(f) not in sorttt and len(f) >= 50:
                                    sorttt.append(len(f))
                            sorttt.sort()
                            results.append({
                                    "Name": NAME,
                                    "Description": desc,
                                    "Fragment_Length": sorttt
                                })
                        except:
                            pass

# Create DataFrame
df = pd.DataFrame(results)

# Print full table
print(df.to_string(index=False))

# Optional: save results
# df.to_excel("restriction_results.xlsx", index=False)
# df.to_csv("restriction_results.csv", index=False)
# Out:
#          Name                                                                  Description        Fragment_Length
#    AP022572.1             AP022572.1 Mycobacterium shottsii JCM 12657 DNA, complete genome [452, 700, 1100, 2042]
# NZ_CP014860.2 NZ_CP014860.2 Mycobacterium shottsii strain M175 chromosome, complete genome [452, 700, 1100, 2042]

# %%
from Bio.Seq import Seq
from Bio import SeqIO
from Bio.Restriction import *
import pandas as pd
import os

# change path base to your device
path = "F:/dr ibrhim/ncbi/sponigae/ncbi_dataset/data"

P1 = "TGCTTAACACATGCAAGTCGAACG"
P = Seq("GTTTCCCGCTTAGATGCTTTCAG").reverse_complement()
P2 = str(P)

results = []   # store results for dataframe

dir_list = os.listdir(path)

for i in dir_list:
    inpu = os.listdir(os.path.join(path, i))
    for s in inpu:
        if s.__contains__(i):
            FASTAFILE = SeqIO.parse(os.path.join(path, i, s), 'fasta')
            for fasta in FASTAFILE:
                NAME, SEQUENCE, desc = str(fasta.name), str(fasta.seq), str(fasta.description)

                # Forward strand
                if P1 in SEQUENCE and P2 in SEQUENCE:
                    subsequence = SEQUENCE[SEQUENCE.index(P1):SEQUENCE.index(P2) + len(P2)]
                    try:
                        sorttt = []
                        g = Tsp45I.catalyze(Seq(subsequence))
                        if len(g) < 2:
                            continue
                        for f in g:
                            if len(f) not in sorttt and len(f) >= 50:
                                sorttt.append(len(f))
                        sorttt.sort()
                        results.append({
                                "Name": NAME,
                                "Description": desc,
                                "Fragment_Length": sorttt
                            })
                    except:
                        pass

                # Reverse complement strand
                else:
                    m = str(Seq(fasta.seq).complement())[::-1]
                    if P1 in m and P2 in m:
                        assemply_sequence = m[m.index(P1):m.index(P2) + len(P2)]
                        try:
                            sorttt = []
                            g = Tsp45I.catalyze(Seq(assemply_sequence))
                            if len(g) < 2:
                                continue
                            for f in g:
                                if len(f) not in sorttt and len(f) >= 50:
                                    sorttt.append(len(f))
                            sorttt.sort()
                            results.append({
                                    "Name": NAME,
                                    "Description": desc,
                                    "Fragment_Length": sorttt
                                })
                        except:
                            pass

# Create DataFrame
df = pd.DataFrame(results)

# Print full table
print(df.to_string(index=False))

# Optional: save results
# df.to_excel("restriction_results.xlsx", index=False)
# df.to_csv("restriction_results.csv", index=False)
# Out:
#          Name                                                                      Description              Fragment_Length
# NZ_CP046600.1 NZ_CP046600.1 Mycobacterium spongiae strain FSD4b-SM chromosome, complete genome [211, 308, 1140, 1344, 1749]

# %%
from Bio.Seq import Seq
from Bio import SeqIO
from Bio.Restriction import *
import pandas as pd
import os

# change path base to your device
path = "F:/dr ibrhim/ncbi/stomatepiae/ncbi_dataset/data"

P1 = "TGCTTAACACATGCAAGTCGAACG"
P = Seq("GTTTCCCGCTTAGATGCTTTCAG").reverse_complement()
P2 = str(P)

results = []   # store results for dataframe

dir_list = os.listdir(path)

for i in dir_list:
    inpu = os.listdir(os.path.join(path, i))
    for s in inpu:
        if s.__contains__(i):
            FASTAFILE = SeqIO.parse(os.path.join(path, i, s), 'fasta')
            for fasta in FASTAFILE:
                NAME, SEQUENCE, desc = str(fasta.name), str(fasta.seq), str(fasta.description)

                # Forward strand
                if P1 in SEQUENCE and P2 in SEQUENCE:
                    subsequence = SEQUENCE[SEQUENCE.index(P1):SEQUENCE.index(P2) + len(P2)]
                    try:
                        sorttt = []
                        g = Tsp45I.catalyze(Seq(subsequence))
                        if len(g) < 2:
                            continue
                        for f in g:
                            if len(f) not in sorttt and len(f) >= 50:
                                sorttt.append(len(f))
                        sorttt.sort()
                        results.append({
                                "Name": NAME,
                                "Description": desc,
                                "Fragment_Length": sorttt
                            })
                    except:
                        pass

                # Reverse complement strand
                else:
                    m = str(Seq(fasta.seq).complement())[::-1]
                    if P1 in m and P2 in m:
                        assemply_sequence = m[m.index(P1):m.index(P2) + len(P2)]
                        try:
                            sorttt = []
                            g = Tsp45I.catalyze(Seq(assemply_sequence))
                            if len(g) < 2:
                                continue
                            for f in g:
                                if len(f) not in sorttt and len(f) >= 50:
                                    sorttt.append(len(f))
                            sorttt.sort()
                            results.append({
                                    "Name": NAME,
                                    "Description": desc,
                                    "Fragment_Length": sorttt
                                })
                        except:
                            pass

# Create DataFrame
df = pd.DataFrame(results)

# Print full table
print(df.to_string(index=False))

# Optional: save results
# df.to_excel("restriction_results.xlsx", index=False)
# df.to_csv("restriction_results.csv", index=False)
# Out:
#          Name                                                                          Description        Fragment_Length
# NZ_AP022587.1 NZ_AP022587.1 Mycobacterium stomatepiae strain JCM 17783 chromosome, complete genome [408, 929, 1340, 2034]

# %%
from Bio.Seq import Seq
from Bio import SeqIO
from Bio.Restriction import *
import pandas as pd
import os

# change path base to your device
path = "F:/dr ibrhim/ncbi/uclearns/ncbi_dataset/data"

P1 = "TGCTTAACACATGCAAGTCGAACG"
P = Seq("GTTTCCCGCTTAGATGCTTTCAG").reverse_complement()
P2 = str(P)

results = []   # store results for dataframe

dir_list = os.listdir(path)

for i in dir_list:
    inpu = os.listdir(os.path.join(path, i))
    for s in inpu:
        if s.__contains__(i):
            FASTAFILE = SeqIO.parse(os.path.join(path, i, s), 'fasta')
            for fasta in FASTAFILE:
                NAME, SEQUENCE, desc = str(fasta.name), str(fasta.seq), str(fasta.description)

                # Forward strand
                if P1 in SEQUENCE and P2 in SEQUENCE:
                    subsequence = SEQUENCE[SEQUENCE.index(P1):SEQUENCE.index(P2) + len(P2)]
                    try:
                        sorttt = []
                        g = Tsp45I.catalyze(Seq(subsequence))
                        if len(g) < 2:
                            continue
                        for f in g:
                            if len(f) not in sorttt and len(f) >= 50:
                                sorttt.append(len(f))
                        sorttt.sort()
                        results.append({
                                "Name": NAME,
                                "Description": desc,
                                "Fragment_Length": sorttt
                            })
                    except:
                        pass

                # Reverse complement strand
                else:
                    m = str(Seq(fasta.seq).complement())[::-1]
                    if P1 in m and P2 in m:
                        assemply_sequence = m[m.index(P1):m.index(P2) + len(P2)]
                        try:
                            sorttt = []
                            g = Tsp45I.catalyze(Seq(assemply_sequence))
                            if len(g) < 2:
                                continue
                            for f in g:
                                if len(f) not in sorttt and len(f) >= 50:
                                    sorttt.append(len(f))
                            sorttt.sort()
                            results.append({
                                    "Name": NAME,
                                    "Description": desc,
                                    "Fragment_Length": sorttt
                                })
                        except:
                            pass

# Create DataFrame
df = pd.DataFrame(results)

# Print full table
print(df.to_string(index=False))

# Optional: save results
# df.to_excel("restriction_results.xlsx", index=False)
# df.to_csv("restriction_results.csv", index=False)
# Out:
#          Name                                                                                           Description        Fragment_Length
#   NC_008611.1                                           NC_008611.1 Mycobacterium ulcerans Agy99, complete sequence [452, 892, 1348, 2046]
# NZ_AP017624.1 NZ_AP017624.1 Mycobacterium ulcerans subsp. shinshuense strain ATCC 33728 chromosome, complete genome [452, 892, 1348, 2042]
# NZ_CP083741.1                         NZ_CP083741.1 Mycobacterium ulcerans strain BS123 chromosome, complete genome [452, 892, 1348, 2042]
# NZ_CP085200.1                       NZ_CP085200.1 Mycobacterium ulcerans strain JKD8049 chromosome, complete genome [452, 892, 1348, 2043]
# NZ_CP092429.2                    NZ_CP092429.2 Mycobacterium ulcerans strain ATCC 19423 chromosome, complete genome [452, 892, 1348, 2043]
# NZ_LR135168.1                      NZ_LR135168.1 Mycobacterium ulcerans strain SGL03 isolate ITM032481 chromosome 1 [452, 892, 1348, 2046]
